# %% [markdown]
# ## Why RAG
# - Limited context window
# - LLM knowledge is forzen at the time which it trained
# - hallucination
#
# ## Full rag pipeline
# ![image.png](attachment:image.png)
#
# - the vilot block can be prformed inside a vector databse
# - the steps 5 and 2 may or may not be performed inside the vector dbs
